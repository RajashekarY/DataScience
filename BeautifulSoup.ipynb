# %% [markdown]
# <a href="https://colab.research.google.com/github/RajashekarY/DataScience/blob/master/BeautifulSoup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install beautifulsoup4
# !pip install requests

# %%
import bs4 as bs
import requests as rqst
import numpy as np

# %%
apiKey = '3b3335db45d884b49e1769510874c'# replace this with yours
lat,lon = 17.3663485,78.430859
finalLink = f'https://api.openweathermap.org/data/2.5/onecall?lat={lat}&lon={lon}&appid={apiKey}'
data = rqst.get(finalLink)

# %%
print(data)
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(data.text)

# %%
import json
data_dict = json.loads(data.text)

# %%
print(data_dict['hourly'])
# Out:
# [{'dt': 1621929600, 'temp': 310.67, 'feels_like': 308.34, 'pressure': 1001, 'humidity': 15, 'dew_point': 279.67, 'uvi': 8.89, 'clouds': 79, 'visibility': 10000, 'wind_speed': 6.87, 'wind_deg': 337, 'wind_gust': 8.16, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'pop': 0}, {'dt': 1621933200, 'temp': 310.51, 'feels_like': 308.31, 'pressure': 1001, 'humidity': 16, 'dew_point': 280.48, 'uvi': 6.71, 'clouds': 75, 'visibility': 10000, 'wind_speed': 7.49, 'wind_deg': 332, 'wind_gust': 8.55, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'pop': 0}, {'dt': 1621936800, 'temp': 310.71, 'feels_like': 308.38, 'pressure': 1001, 'humidity': 15, 'dew_point': 279.7, 'uvi': 3.59, 'clouds': 79, 'visibility': 10000, 'wind_speed': 7.49, 'wind_deg': 336, 'wind_gust': 8.73, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'pop': 0}, {'dt': 1621940400, 'temp': 310.61, 'feels_li
# ...

# %%
weather = "https://openweathermap.org/api/one-call-api"
weatherData = rqst.get(weather)

# %%
variable = weatherData.text

# %%
var2 = [heading for heading in variable if variable.startswith("<li>")]

# %%
results = weatherData.find_all('li')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-cbe62bbb7f12> in <module>()
# ----> 1 results = weatherData.find_all('li')
#
# AttributeError: 'Response' object has no attribute 'find_all'

# %%
print(variable)
# Out:
# <!DOCTYPE html>
# <html lang='en'>
#     <head>
#         <!-- smart banner apple -->
#         <meta name="apple-itunes-app" content="app-id=1535923697">
#         <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
#     <meta  http-equiv=Expires content="Tue, Sep 20 2018 15:27:22 GMT">
#     <meta http-equiv="Last-Modified" content="Tue, Sep 20 2018 15:27:22 GMT">
#     <!--<meta http-equiv="X-UA-Compatible" content="IE=edge">-->
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <meta name="keywords" content="weather, world, Openstreetmap, forecast, Openweather, current" >
#     <meta name="description" content="Make only one API call and get all essential weather data for some specific location with our new OpenWeather One Call API. Current weather
# Minute forecast, Hourly forecast for 48 hours, Daily forecast for 7 days, Government weather alerts, Historical weather data for 5 previous days" >
# ...
